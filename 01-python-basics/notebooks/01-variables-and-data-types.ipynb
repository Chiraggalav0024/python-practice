# %%
name = "Chirag"
sec = 'B'
age = 21
height = 6.1
honest = True

# %%
#Normal print use
print("My name is ", name,".")

#using the f strings
print(f"my age is {age}.")

#using .format()
print("My name is {}, and i am {} years old.".format(name,age))
# Out:
# My name is  Chirag .
# my age is 21.
# My name is Chirag, and i am 21 years old.

# %%
name1 = input("Enter another name:")
age1 = int(input("Enter age:"))

# %%
print(f"Hello, My name is {name1} and i am {age1} years old.")
# Out:
# Hello, My name is chandan and i am 19 years old.
