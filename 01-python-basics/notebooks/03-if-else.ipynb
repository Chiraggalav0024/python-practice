# %%
age = int(input("Enter your age:"))
print(f"You entered your age {age}")

if(age<18):
    print("You are minor")
    print("You cant vote")
    if(age<5):
        print("you are a child")

elif(age>18 and age<100):
    print("Your are eligible to vote")

else:
    print("Enter a valid age!")
# Out:
# You entered your age 4
# You are minor
# You cant vote
# you are a child
