# %%
for num in range (1,10):
    print(num)
fruits = ["apple","banana", "pumpkin", "pinapple" ]
for fruit in fruits:
    print(fruit)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# apple
# banana
# pumpkin
# pinapple

# %%
count = 1
while count < 10:
    print(count)
    count+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
