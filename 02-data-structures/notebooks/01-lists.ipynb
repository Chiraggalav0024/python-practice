# %%
mix = ["chilly", "carrot", 4, 6, True, "apple"]
print(mix)
print(mix[-1])
print(mix[0:4])
print(mix[-1:-4])
# Out:
# ['chilly', 'carrot', 4, 6, True, 'apple']
# apple
# ['chilly', 'carrot', 4, 6]
# []
